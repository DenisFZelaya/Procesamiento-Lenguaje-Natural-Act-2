# %%
import argilla as rb

rb.log(
    rb.TextClassificationRecord(text="My first Rubrix example"),
    name='example-dataset'
)

# %%
#!python -m argilla

#!python -m argilla users create --username zelayad --password password123 --roles admin
#!python -m argilla info
#!python -m argilla users generate-apikey --username admin
#!pip install "rubrix[server]"

# !python -m argilla
# Out:
# "kill" no se reconoce como un comando interno o externo,
# programa o archivo por lotes ejecutable.
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# !pip install argilla
# Out:
# ...
#   Using cached argilla-1.29.0-py3-none-any.whl.metadata (17 kB)
# ...
#   Using cached httpx-0.26.0-py3-none-any.whl.metadata (7.6 kB)
# ...
#   Using cached Deprecated-1.2.14-py2.py3-none-any.whl.metadata (5.4 kB)
# ...
#   Using cached pydantic-2.8.2-py3-none-any.whl.metadata (125 kB)
# ...
#   Using cached tqdm-4.66.4-py3-none-any.whl.metadata (57 kB)
# ...
#   Using cached backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# ...
#   Using cached monotonic-1.6-py2.py3-none-any.whl.metadata (1.5 kB)
# ...
#   Using cached rich-13.7.1-py3-none-any.whl.metadata (18 kB)
# ...
#   Using cached typer-0.9.4-py3-none-any.whl.metadata (14 kB)
# ...
#   Using cached anyio-4.4.0-py3-none-any.whl.metadata (4.6 kB)
# ...
#   Using cached httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# ...
#   Using cached idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# ...
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# ...
#   Using cached h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# ...
#   Using cached pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# ...
